# %%
import os
import random
import pandas as pd
import numpy as np
import gzip
import subprocess
from loguru import logger
from langchain.prompts import PromptTemplate
from tqdm import tqdm

def parse(path: str) -> dict:
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def get_df(path: str) -> pd.DataFrame:
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %%
def read_data(dir: str, dataset: str) -> tuple[pd.DataFrame, pd.DataFrame]:
    raw_path = os.path.join(dir, 'raw_data')
    data_file = 'reviews_{}_5.json.gz'.format(dataset)
    meta_file = 'meta_{}.json.gz'.format(dataset)
    data_df = get_df(os.path.join(raw_path, data_file))
    meta_df = get_df(os.path.join(raw_path, meta_file))
    return data_df, meta_df

# %%
dir = '../data/Beauty'
dataset = 'Beauty'

# %%
df = read_data(dir, dataset)

# %%
df
# Out:
# (            reviewerID        asin  \
#  0       A1YJEY40YUW4SE  7806397051
#  1        A60XNB876KYML  7806397051
#  2       A3G6XNM240RMWA  7806397051
#  3       A1PQFP6SAJ6D80  7806397051
#  4       A38FVHZTNQ271F  7806397051
#  ...                ...         ...
#  198497  A2BLFCOPSMBOZ9  B00LLPT4HI
#  198498  A1UQBFCERIP7VJ  B00LLPT4HI
#  198499  A35Q0RBM3YNQNF  B00LLPT4HI
#  198500  A3LGT6UZL99IW1  B00LLPT4HI
#  198501  A3UJRNI8UR4871  B00LLPT4HI
#
#                                              reviewerName helpful  \
#  0                                                 Andrea  [3, 4]
#  1                                             Jessica H.  [1, 1]
#  2                                                  Karen  [0, 1]
#  3                                                  Norah  [2, 2]
#  4                                              Nova Amor  [0, 0]
#  ...                                                  ...     ...
#  198497                                     Dave Edmiston  [0, 0]
#  198498                                    Margaret Picky  [0, 0]
#  198499                                           M. Hill  [0, 0]
#  198500  Richard C. Drew "Anaal Nathra/Uthe vas Bethod...  [0, 0]
#  198501                               Wulfstan "wulfstan"  [0, 1]
#
#                                                 reviewText  overall  \
#  0       Very oily and creamy. Not at all what I expect...      1.0
#  1       This palette was a decent price and I was look...      3.0
#  2       The texture of this concealer pallet is fantas...      4.0
#  3       I really can't tell what exactly this thing is...      2.0
#  4       It was a little smaller than I expected, but t...      3.0
#  ...                                                   ...      ...
#  198497  Just a little dab of this shea butter should b...      5.0
#  198498  This shea butter is completely raw and unrefin...      5.0
#  198499  The skin is the body's largest organ and it ab...      5.0
#  198500  I have very dry elbows and knees.  I have a to...      5.0
#  198501  This is 100% pure Shea Butter. Do not mistake ...      5.0
#
#                                                  summary  unixReviewTime  \
#  0                                Don't waste your money      1391040000
#  1                                           OK Palette!      1397779200
#  2                                         great quality      1378425600
#  3                                Do not work on my face      1386460800
#  4                                            It's okay.      1382140800
#  ...                                                 ...             ...
#  198497                                  A little dab...      1405468800
#  198498                     Pure organic raw shea butter      1405296000
#  198499  One Pound Organic Grade A Unrefined Shea Butter      1405468800
#  198500                           This stuff is amazing!      1405382400
#  198501                                The "Real Stuff"!      1405987200
#
#           reviewTime
#  0       01 30, 2014
#  1       04 18, 2014
#  2        09 6, 2013
#  3        12 8, 2013
#  4       10 19, 2013
#  ...             ...
#  198497  07 16, 2014
#  198498  07 14, 2014
#  198499  07 16, 2014
#  198500  07 15, 2014
#  198501  07 22, 2014
#
#  [198502 rows x 9 columns],
#                asin                                        description  \
#  0       0205616461  As we age, our once youthful, healthy skin suc...
#  1       0558925278  Mineral Powder Brush--Apply powder or mineral ...
#  2       0733001998  From the Greek island of Chios, this Mastiha b...
#  3       0737104473  Limited edition Hello Kitty Lipstick featuring...
#  4       0762451459  The mermaid is an elusive (okay, mythical) cre...
#  ...            ...                                                ...
#  259199  B00LP2YB8E  Color: White\nFullness72 inches\nCenter Gather...
#  259200  B00LOS7MEE  The secret to long lasting colors, healthy nai...
#  259201  B00LPVG6V0  ResQ Organics Face & Body Wash - With Aloe Ver...
#  259202  B00LTDUHJQ  Color: White\n2 Tier \nFullness 72 inches\nSew...
#  259203  B00LU0LTOU  The bags produced by us are 100% ECO friendly ...
#
#                                                      title  \
#  0       Bio-Active Anti-Aging Serum (Firming Ultra-Hyd...
#  1       Eco Friendly Ecotools Quality Natural Bamboo C...
#  2                                     Mastiha Body Lotion
#  3       Hello Kitty Lustre Lipstick (See sellers comme...
#  4             Stephanie Johnson Mermaid Round Snap Mirror
#  ...                                                   ...
#  259199  2t 2t Edge Crystal Rhinestones Bridal Wedding ...
#  259200  French Manicure Gel Nail Polish Set - &quot;Se...
#  259201  ResQ Organics Face &amp; Body Wash - Aloe Vera...
#  259202  2 Tier Tulle Elbow Wedding Veil with Ribbon Ed...
#  259203  *ECOCRAFTWORLD* GENUINE BUFFALO LEATHER TRAVEL...
#
#                                                      imUrl  \
#  0       http://ecx.images-amazon.com/images/I/41DecrGO...
#  1       http://ecx.images-amazon.com/images/I/51L%2BzY...
#  2       http://ecx.images-amazon.com/images/I/311WK5y1...
#  3       http://ecx.images-amazon.com/images/I/31u6Hrzk...
#  4       http://ecx.images-amazon.com/images/I/41y2%2BF...
#  ...                                                   ...
#  259199  http://ecx.images-amazon.com/images/I/41E630m-...
#  259200  http://ecx.images-amazon.com/images/I/41skHL1O...
#  259201  http://ecx.images-amazon.com/images/I/31C1w4Ku...
#  259202  http://ecx.images-amazon.com/images/I/51%2B%2B...
#  259203  http://ecx.images-amazon.com/images/I/41kXSEch...
#
#                                   salesRank  \
#  0       {'Health & Personal Care': 461765}
#  1                       {'Beauty': 402875}
#  2                       {'Beauty': 540255}
#  3                       {'Beauty': 931125}
#  4                                      NaN
#  ...                                    ...
#  259199                                 NaN
#  259200                  {'Beauty': 108820}
#  259201                                 NaN
#  259202                                 NaN
#  259203                                 NaN
#
#                                                 categories   price  \
#  0       [[Beauty, Skin Care, Face, Creams & Moisturize...     NaN
#  1       [[Beauty, Tools & Accessories, Makeup Brushes ...     NaN
#  2       [[Beauty, Skin Care, Body, Moisturizers, Lotio...     NaN
#  3                      [[Beauty, Makeup, Lips, Lipstick]]     NaN
#  4       [[Beauty, Tools & Accessories, Mirrors, Makeup...   19.98
#  ...                                                   ...     ...
#  259199  [[Beauty, Hair Care, Styling Tools, Styling Ac...     NaN
#  259200             [[Beauty, Makeup, Nails, Nail Polish]]     NaN
#  259201  [[Beauty, Skin Care, Face, Creams & Moisturize...     NaN
#  259202  [[Beauty, Hair Care, Styling Tools, Styling Ac...     NaN
#  259203  [[Beauty, Tools & Accessories, Bags & Cases, T...  130.00
#
#                                                    related brand
#  0                                                     NaN   NaN
#  1                                                     NaN   NaN
#  2                                                     NaN   NaN
#  3                                                     NaN   NaN
#  4                                                     NaN   NaN
#  ...                                                   ...   ...
#  259199                                                NaN   NaN
#  259200  {'also_viewed': ['B0057JCYYE', 'B00LMXHR1Y', '...   NaN
#  259201                                                NaN   NaN
#  259202                                                NaN   NaN
#  259203  {'also_viewed': ['B00JWX6OOW', 'B00L4HJCZC', '...   NaN
#
#  [259204 rows x 9 columns])

# %%
type(df)
# Out:
# tuple

# %%
df[0]
# Out:
#             reviewerID        asin  \
# 0       A1YJEY40YUW4SE  7806397051
# 1        A60XNB876KYML  7806397051
# 2       A3G6XNM240RMWA  7806397051
# 3       A1PQFP6SAJ6D80  7806397051
# 4       A38FVHZTNQ271F  7806397051
# ...                ...         ...
# 198497  A2BLFCOPSMBOZ9  B00LLPT4HI
# 198498  A1UQBFCERIP7VJ  B00LLPT4HI
# 198499  A35Q0RBM3YNQNF  B00LLPT4HI
# 198500  A3LGT6UZL99IW1  B00LLPT4HI
# 198501  A3UJRNI8UR4871  B00LLPT4HI
#
#                                             reviewerName helpful  \
# 0                                                 Andrea  [3, 4]
# 1                                             Jessica H.  [1, 1]
# 2                                                  Karen  [0, 1]
# 3                                                  Norah  [2, 2]
# 4                                              Nova Amor  [0, 0]
# ...                                                  ...     ...
# 198497                                     Dave Edmiston  [0, 0]
# 198498                                    Margaret Picky  [0, 0]
# 198499                                           M. Hill  [0, 0]
# 198500  Richard C. Drew "Anaal Nathra/Uthe vas Bethod...  [0, 0]
# 198501                               Wulfstan "wulfstan"  [0, 1]
#
#                                                reviewText  overall  \
# 0       Very oily and creamy. Not at all what I expect...      1.0
# 1       This palette was a decent price and I was look...      3.0
# 2       The texture of this concealer pallet is fantas...      4.0
# 3       I really can't tell what exactly this thing is...      2.0
# 4       It was a little smaller than I expected, but t...      3.0
# ...                                                   ...      ...
# 198497  Just a little dab of this shea butter should b...      5.0
# 198498  This shea butter is completely raw and unrefin...      5.0
# 198499  The skin is the body's largest organ and it ab...      5.0
# 198500  I have very dry elbows and knees.  I have a to...      5.0
# 198501  This is 100% pure Shea Butter. Do not mistake ...      5.0
#
#                                                 summary  unixReviewTime  \
# 0                                Don't waste your money      1391040000
# 1                                           OK Palette!      1397779200
# 2                                         great quality      1378425600
# 3                                Do not work on my face      1386460800
# 4                                            It's okay.      1382140800
# ...                                                 ...             ...
# 198497                                  A little dab...      1405468800
# 198498                     Pure organic raw shea butter      1405296000
# 198499  One Pound Organic Grade A Unrefined Shea Butter      1405468800
# 198500                           This stuff is amazing!      1405382400
# 198501                                The "Real Stuff"!      1405987200
#
#          reviewTime
# 0       01 30, 2014
# 1       04 18, 2014
# 2        09 6, 2013
# 3        12 8, 2013
# 4       10 19, 2013
# ...             ...
# 198497  07 16, 2014
# 198498  07 14, 2014
# 198499  07 16, 2014
# 198500  07 15, 2014
# 198501  07 22, 2014
#
# [198502 rows x 9 columns]

# %%
joined_dataset = df[0].merge(df[1], on = 'asin')

# %%
joined_dataset
# Out:
#             reviewerID        asin  \
# 0       A1YJEY40YUW4SE  7806397051
# 1        A60XNB876KYML  7806397051
# 2       A3G6XNM240RMWA  7806397051
# 3       A1PQFP6SAJ6D80  7806397051
# 4       A38FVHZTNQ271F  7806397051
# ...                ...         ...
# 198497  A2BLFCOPSMBOZ9  B00LLPT4HI
# 198498  A1UQBFCERIP7VJ  B00LLPT4HI
# 198499  A35Q0RBM3YNQNF  B00LLPT4HI
# 198500  A3LGT6UZL99IW1  B00LLPT4HI
# 198501  A3UJRNI8UR4871  B00LLPT4HI
#
#                                             reviewerName helpful  \
# 0                                                 Andrea  [3, 4]
# 1                                             Jessica H.  [1, 1]
# 2                                                  Karen  [0, 1]
# 3                                                  Norah  [2, 2]
# 4                                              Nova Amor  [0, 0]
# ...                                                  ...     ...
# 198497                                     Dave Edmiston  [0, 0]
# 198498                                    Margaret Picky  [0, 0]
# 198499                                           M. Hill  [0, 0]
# 198500  Richard C. Drew "Anaal Nathra/Uthe vas Bethod...  [0, 0]
# 198501                               Wulfstan "wulfstan"  [0, 1]
#
#                                                reviewText  overall  \
# 0       Very oily and creamy. Not at all what I expect...      1.0
# 1       This palette was a decent price and I was look...      3.0
# 2       The texture of this concealer pallet is fantas...      4.0
# 3       I really can't tell what exactly this thing is...      2.0
# 4       It was a little smaller than I expected, but t...      3.0
# ...                                                   ...      ...
# 198497  Just a little dab of this shea butter should b...      5.0
# 198498  This shea butter is completely raw and unrefin...      5.0
# 198499  The skin is the body's largest organ and it ab...      5.0
# 198500  I have very dry elbows and knees.  I have a to...      5.0
# 198501  This is 100% pure Shea Butter. Do not mistake ...      5.0
#
#                                                 summary  unixReviewTime  \
# 0                                Don't waste your money      1391040000
# 1                                           OK Palette!      1397779200
# 2                                         great quality      1378425600
# 3                                Do not work on my face      1386460800
# 4                                            It's okay.      1382140800
# ...                                                 ...             ...
# 198497                                  A little dab...      1405468800
# 198498                     Pure organic raw shea butter      1405296000
# 198499  One Pound Organic Grade A Unrefined Shea Butter      1405468800
# 198500                           This stuff is amazing!      1405382400
# 198501                                The "Real Stuff"!      1405987200
#
#          reviewTime                                        description  \
# 0       01 30, 2014  An extensive range of 15 multiple vibrant long...
# 1       04 18, 2014  An extensive range of 15 multiple vibrant long...
# 2        09 6, 2013  An extensive range of 15 multiple vibrant long...
# 3        12 8, 2013  An extensive range of 15 multiple vibrant long...
# 4       10 19, 2013  An extensive range of 15 multiple vibrant long...
# ...             ...                                                ...
# 198497  07 16, 2014  Ingredients:\n100% Pure, Unrefined, Organic Af...
# 198498  07 14, 2014  Ingredients:\n100% Pure, Unrefined, Organic Af...
# 198499  07 16, 2014  Ingredients:\n100% Pure, Unrefined, Organic Af...
# 198500  07 15, 2014  Ingredients:\n100% Pure, Unrefined, Organic Af...
# 198501  07 22, 2014  Ingredients:\n100% Pure, Unrefined, Organic Af...
#
#                                                     title  \
# 0       WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 1       WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 2       WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 3       WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 4       WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# ...                                                   ...
# 198497  100% Organic Raw Unrefined African Shea Butter...
# 198498  100% Organic Raw Unrefined African Shea Butter...
# 198499  100% Organic Raw Unrefined African Shea Butter...
# 198500  100% Organic Raw Unrefined African Shea Butter...
# 198501  100% Organic Raw Unrefined African Shea Butter...
#
#                                                     imUrl          salesRank  \
# 0       http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 1       http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 2       http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 3       http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 4       http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# ...                                                   ...                ...
# 198497  http://ecx.images-amazon.com/images/I/41up5%2B...   {'Beauty': 1265}
# 198498  http://ecx.images-amazon.com/images/I/41up5%2B...   {'Beauty': 1265}
# 198499  http://ecx.images-amazon.com/images/I/41up5%2B...   {'Beauty': 1265}
# 198500  http://ecx.images-amazon.com/images/I/41up5%2B...   {'Beauty': 1265}
# 198501  http://ecx.images-amazon.com/images/I/41up5%2B...   {'Beauty': 1265}
#
#                                                categories  price  \
# 0       [[Beauty, Makeup, Face, Concealers & Neutraliz...   5.04
# 1       [[Beauty, Makeup, Face, Concealers & Neutraliz...   5.04
# 2       [[Beauty, Makeup, Face, Concealers & Neutraliz...   5.04
# 3       [[Beauty, Makeup, Face, Concealers & Neutraliz...   5.04
# 4       [[Beauty, Makeup, Face, Concealers & Neutraliz...   5.04
# ...                                                   ...    ...
# 198497  [[Beauty, Skin Care, Body, Moisturizers, Lotio...   9.97
# 198498  [[Beauty, Skin Care, Body, Moisturizers, Lotio...   9.97
# 198499  [[Beauty, Skin Care, Body, Moisturizers, Lotio...   9.97
# 198500  [[Beauty, Skin Care, Body, Moisturizers, Lotio...   9.97
# 198501  [[Beauty, Skin Care, Body, Moisturizers, Lotio...   9.97
#
#                                                   related brand
# 0       {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 1       {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 2       {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 3       {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 4       {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# ...                                                   ...   ...
# 198497  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...   NaN
# 198498  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...   NaN
# 198499  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...   NaN
# 198500  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...   NaN
# 198501  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...   NaN
#
# [198502 rows x 17 columns]

# %%
reindex_dataset = joined_dataset.set_index(['reviewerID', 'asin'])

# %%
reindex_dataset
# Out:
#                                                                reviewerName  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051                                            Andrea
# A60XNB876KYML  7806397051                                        Jessica H.
# A3G6XNM240RMWA 7806397051                                             Karen
# A1PQFP6SAJ6D80 7806397051                                             Norah
# A38FVHZTNQ271F 7806397051                                         Nova Amor
# ...                                                                     ...
# A2BLFCOPSMBOZ9 B00LLPT4HI                                     Dave Edmiston
# A1UQBFCERIP7VJ B00LLPT4HI                                    Margaret Picky
# A35Q0RBM3YNQNF B00LLPT4HI                                           M. Hill
# A3LGT6UZL99IW1 B00LLPT4HI  Richard C. Drew "Anaal Nathra/Uthe vas Bethod...
# A3UJRNI8UR4871 B00LLPT4HI                               Wulfstan "wulfstan"
#
#                           helpful  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  [3, 4]
# A60XNB876KYML  7806397051  [1, 1]
# A3G6XNM240RMWA 7806397051  [0, 1]
# A1PQFP6SAJ6D80 7806397051  [2, 2]
# A38FVHZTNQ271F 7806397051  [0, 0]
# ...                           ...
# A2BLFCOPSMBOZ9 B00LLPT4HI  [0, 0]
# A1UQBFCERIP7VJ B00LLPT4HI  [0, 0]
# A35Q0RBM3YNQNF B00LLPT4HI  [0, 0]
# A3LGT6UZL99IW1 B00LLPT4HI  [0, 0]
# A3UJRNI8UR4871 B00LLPT4HI  [0, 1]
#
#                                                                   reviewText  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  Very oily and creamy. Not at all what I expect...
# A60XNB876KYML  7806397051  This palette was a decent price and I was look...
# A3G6XNM240RMWA 7806397051  The texture of this concealer pallet is fantas...
# A1PQFP6SAJ6D80 7806397051  I really can't tell what exactly this thing is...
# A38FVHZTNQ271F 7806397051  It was a little smaller than I expected, but t...
# ...                                                                      ...
# A2BLFCOPSMBOZ9 B00LLPT4HI  Just a little dab of this shea butter should b...
# A1UQBFCERIP7VJ B00LLPT4HI  This shea butter is completely raw and unrefin...
# A35Q0RBM3YNQNF B00LLPT4HI  The skin is the body's largest organ and it ab...
# A3LGT6UZL99IW1 B00LLPT4HI  I have very dry elbows and knees.  I have a to...
# A3UJRNI8UR4871 B00LLPT4HI  This is 100% pure Shea Butter. Do not mistake ...
#
#                            overall  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051      1.0
# A60XNB876KYML  7806397051      3.0
# A3G6XNM240RMWA 7806397051      4.0
# A1PQFP6SAJ6D80 7806397051      2.0
# A38FVHZTNQ271F 7806397051      3.0
# ...                            ...
# A2BLFCOPSMBOZ9 B00LLPT4HI      5.0
# A1UQBFCERIP7VJ B00LLPT4HI      5.0
# A35Q0RBM3YNQNF B00LLPT4HI      5.0
# A3LGT6UZL99IW1 B00LLPT4HI      5.0
# A3UJRNI8UR4871 B00LLPT4HI      5.0
#
#                                                                    summary  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051                           Don't waste your money
# A60XNB876KYML  7806397051                                      OK Palette!
# A3G6XNM240RMWA 7806397051                                    great quality
# A1PQFP6SAJ6D80 7806397051                           Do not work on my face
# A38FVHZTNQ271F 7806397051                                       It's okay.
# ...                                                                    ...
# A2BLFCOPSMBOZ9 B00LLPT4HI                                  A little dab...
# A1UQBFCERIP7VJ B00LLPT4HI                     Pure organic raw shea butter
# A35Q0RBM3YNQNF B00LLPT4HI  One Pound Organic Grade A Unrefined Shea Butter
# A3LGT6UZL99IW1 B00LLPT4HI                           This stuff is amazing!
# A3UJRNI8UR4871 B00LLPT4HI                                The "Real Stuff"!
#
#                            unixReviewTime   reviewTime  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051      1391040000  01 30, 2014
# A60XNB876KYML  7806397051      1397779200  04 18, 2014
# A3G6XNM240RMWA 7806397051      1378425600   09 6, 2013
# A1PQFP6SAJ6D80 7806397051      1386460800   12 8, 2013
# A38FVHZTNQ271F 7806397051      1382140800  10 19, 2013
# ...                                   ...          ...
# A2BLFCOPSMBOZ9 B00LLPT4HI      1405468800  07 16, 2014
# A1UQBFCERIP7VJ B00LLPT4HI      1405296000  07 14, 2014
# A35Q0RBM3YNQNF B00LLPT4HI      1405468800  07 16, 2014
# A3LGT6UZL99IW1 B00LLPT4HI      1405382400  07 15, 2014
# A3UJRNI8UR4871 B00LLPT4HI      1405987200  07 22, 2014
#
#                                                                  description  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  An extensive range of 15 multiple vibrant long...
# A60XNB876KYML  7806397051  An extensive range of 15 multiple vibrant long...
# A3G6XNM240RMWA 7806397051  An extensive range of 15 multiple vibrant long...
# A1PQFP6SAJ6D80 7806397051  An extensive range of 15 multiple vibrant long...
# A38FVHZTNQ271F 7806397051  An extensive range of 15 multiple vibrant long...
# ...                                                                      ...
# A2BLFCOPSMBOZ9 B00LLPT4HI  Ingredients:\n100% Pure, Unrefined, Organic Af...
# A1UQBFCERIP7VJ B00LLPT4HI  Ingredients:\n100% Pure, Unrefined, Organic Af...
# A35Q0RBM3YNQNF B00LLPT4HI  Ingredients:\n100% Pure, Unrefined, Organic Af...
# A3LGT6UZL99IW1 B00LLPT4HI  Ingredients:\n100% Pure, Unrefined, Organic Af...
# A3UJRNI8UR4871 B00LLPT4HI  Ingredients:\n100% Pure, Unrefined, Organic Af...
#
#                                                                        title  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# A60XNB876KYML  7806397051  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# A3G6XNM240RMWA 7806397051  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# A1PQFP6SAJ6D80 7806397051  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# A38FVHZTNQ271F 7806397051  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# ...                                                                      ...
# A2BLFCOPSMBOZ9 B00LLPT4HI  100% Organic Raw Unrefined African Shea Butter...
# A1UQBFCERIP7VJ B00LLPT4HI  100% Organic Raw Unrefined African Shea Butter...
# A35Q0RBM3YNQNF B00LLPT4HI  100% Organic Raw Unrefined African Shea Butter...
# A3LGT6UZL99IW1 B00LLPT4HI  100% Organic Raw Unrefined African Shea Butter...
# A3UJRNI8UR4871 B00LLPT4HI  100% Organic Raw Unrefined African Shea Butter...
#
#                                                                        imUrl  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  http://ecx.images-amazon.com/images/I/41Rn18Oe...
# A60XNB876KYML  7806397051  http://ecx.images-amazon.com/images/I/41Rn18Oe...
# A3G6XNM240RMWA 7806397051  http://ecx.images-amazon.com/images/I/41Rn18Oe...
# A1PQFP6SAJ6D80 7806397051  http://ecx.images-amazon.com/images/I/41Rn18Oe...
# A38FVHZTNQ271F 7806397051  http://ecx.images-amazon.com/images/I/41Rn18Oe...
# ...                                                                      ...
# A2BLFCOPSMBOZ9 B00LLPT4HI  http://ecx.images-amazon.com/images/I/41up5%2B...
# A1UQBFCERIP7VJ B00LLPT4HI  http://ecx.images-amazon.com/images/I/41up5%2B...
# A35Q0RBM3YNQNF B00LLPT4HI  http://ecx.images-amazon.com/images/I/41up5%2B...
# A3LGT6UZL99IW1 B00LLPT4HI  http://ecx.images-amazon.com/images/I/41up5%2B...
# A3UJRNI8UR4871 B00LLPT4HI  http://ecx.images-amazon.com/images/I/41up5%2B...
#
#                                    salesRank  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  {'Beauty': 10486}
# A60XNB876KYML  7806397051  {'Beauty': 10486}
# A3G6XNM240RMWA 7806397051  {'Beauty': 10486}
# A1PQFP6SAJ6D80 7806397051  {'Beauty': 10486}
# A38FVHZTNQ271F 7806397051  {'Beauty': 10486}
# ...                                      ...
# A2BLFCOPSMBOZ9 B00LLPT4HI   {'Beauty': 1265}
# A1UQBFCERIP7VJ B00LLPT4HI   {'Beauty': 1265}
# A35Q0RBM3YNQNF B00LLPT4HI   {'Beauty': 1265}
# A3LGT6UZL99IW1 B00LLPT4HI   {'Beauty': 1265}
# A3UJRNI8UR4871 B00LLPT4HI   {'Beauty': 1265}
#
#                                                                   categories  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  [[Beauty, Makeup, Face, Concealers & Neutraliz...
# A60XNB876KYML  7806397051  [[Beauty, Makeup, Face, Concealers & Neutraliz...
# A3G6XNM240RMWA 7806397051  [[Beauty, Makeup, Face, Concealers & Neutraliz...
# A1PQFP6SAJ6D80 7806397051  [[Beauty, Makeup, Face, Concealers & Neutraliz...
# A38FVHZTNQ271F 7806397051  [[Beauty, Makeup, Face, Concealers & Neutraliz...
# ...                                                                      ...
# A2BLFCOPSMBOZ9 B00LLPT4HI  [[Beauty, Skin Care, Body, Moisturizers, Lotio...
# A1UQBFCERIP7VJ B00LLPT4HI  [[Beauty, Skin Care, Body, Moisturizers, Lotio...
# A35Q0RBM3YNQNF B00LLPT4HI  [[Beauty, Skin Care, Body, Moisturizers, Lotio...
# A3LGT6UZL99IW1 B00LLPT4HI  [[Beauty, Skin Care, Body, Moisturizers, Lotio...
# A3UJRNI8UR4871 B00LLPT4HI  [[Beauty, Skin Care, Body, Moisturizers, Lotio...
#
#                            price  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051   5.04
# A60XNB876KYML  7806397051   5.04
# A3G6XNM240RMWA 7806397051   5.04
# A1PQFP6SAJ6D80 7806397051   5.04
# A38FVHZTNQ271F 7806397051   5.04
# ...                          ...
# A2BLFCOPSMBOZ9 B00LLPT4HI   9.97
# A1UQBFCERIP7VJ B00LLPT4HI   9.97
# A35Q0RBM3YNQNF B00LLPT4HI   9.97
# A3LGT6UZL99IW1 B00LLPT4HI   9.97
# A3UJRNI8UR4871 B00LLPT4HI   9.97
#
#                                                                      related  \
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...
# A60XNB876KYML  7806397051  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...
# A3G6XNM240RMWA 7806397051  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...
# A1PQFP6SAJ6D80 7806397051  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...
# A38FVHZTNQ271F 7806397051  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...
# ...                                                                      ...
# A2BLFCOPSMBOZ9 B00LLPT4HI  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...
# A1UQBFCERIP7VJ B00LLPT4HI  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...
# A35Q0RBM3YNQNF B00LLPT4HI  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...
# A3LGT6UZL99IW1 B00LLPT4HI  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...
# A3UJRNI8UR4871 B00LLPT4HI  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...
#
#                           brand
# reviewerID     asin
# A1YJEY40YUW4SE 7806397051  COKA
# A60XNB876KYML  7806397051  COKA
# A3G6XNM240RMWA 7806397051  COKA
# A1PQFP6SAJ6D80 7806397051  COKA
# A38FVHZTNQ271F 7806397051  COKA
# ...                         ...
# A2BLFCOPSMBOZ9 B00LLPT4HI   NaN
# A1UQBFCERIP7VJ B00LLPT4HI   NaN
# A35Q0RBM3YNQNF B00LLPT4HI   NaN
# A3LGT6UZL99IW1 B00LLPT4HI   NaN
# A3UJRNI8UR4871 B00LLPT4HI   NaN
#
# [198502 rows x 15 columns]

# %%
'''
TODO:
- turn dataset to {id: (reviewerID, asin), attribute: string}
- export to csv
'''
# Out:
# '\nTODO:\n- turn dataset to {id: (reviewerID, asin), attribute: string}\n- export to csv\n'

# %%
name = 'table_data'
reindex_dataset.to_csv(f'{dir}/{name}.csv', index = True)

# %%
table_data = pd.read_csv(f'{dir}/{name}.csv')

# %%
table_data.head()
# Out:
#        reviewerID        asin reviewerName helpful  \
# 0  A1YJEY40YUW4SE  7806397051       Andrea  [3, 4]
# 1   A60XNB876KYML  7806397051   Jessica H.  [1, 1]
# 2  A3G6XNM240RMWA  7806397051        Karen  [0, 1]
# 3  A1PQFP6SAJ6D80  7806397051        Norah  [2, 2]
# 4  A38FVHZTNQ271F  7806397051    Nova Amor  [0, 0]
#
#                                           reviewText  overall  \
# 0  Very oily and creamy. Not at all what I expect...      1.0
# 1  This palette was a decent price and I was look...      3.0
# 2  The texture of this concealer pallet is fantas...      4.0
# 3  I really can't tell what exactly this thing is...      2.0
# 4  It was a little smaller than I expected, but t...      3.0
#
#                   summary  unixReviewTime   reviewTime  \
# 0  Don't waste your money      1391040000  01 30, 2014
# 1             OK Palette!      1397779200  04 18, 2014
# 2           great quality      1378425600   09 6, 2013
# 3  Do not work on my face      1386460800   12 8, 2013
# 4              It's okay.      1382140800  10 19, 2013
#
#                                          description  \
# 0  An extensive range of 15 multiple vibrant long...
# 1  An extensive range of 15 multiple vibrant long...
# 2  An extensive range of 15 multiple vibrant long...
# 3  An extensive range of 15 multiple vibrant long...
# 4  An extensive range of 15 multiple vibrant long...
#
#                                                title  \
# 0  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 1  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 2  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 3  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 4  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
#
#                                                imUrl          salesRank  \
# 0  http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 1  http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 2  http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 3  http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
# 4  http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
#
#                                           categories  price  \
# 0  [['Beauty', 'Makeup', 'Face', 'Concealers & Ne...   5.04
# 1  [['Beauty', 'Makeup', 'Face', 'Concealers & Ne...   5.04
# 2  [['Beauty', 'Makeup', 'Face', 'Concealers & Ne...   5.04
# 3  [['Beauty', 'Makeup', 'Face', 'Concealers & Ne...   5.04
# 4  [['Beauty', 'Makeup', 'Face', 'Concealers & Ne...   5.04
#
#                                              related brand
# 0  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 1  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 2  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 3  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA
# 4  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA

# %%
'''
FLow:
- create new attributes named "attributes" by turn all features except 'reviewerID' and 'asin' to string, then append all of them
'''
# Out:
# '\nFLow:\n- create new attributes named "attributes" by turn all features except reviewId\n'

# %%
df_examples = table_data.iloc[[0],2:]

df_examples
# Out:
#   reviewerName helpful                                         reviewText  \
# 0       Andrea  [3, 4]  Very oily and creamy. Not at all what I expect...
#
#    overall                 summary  unixReviewTime   reviewTime  \
# 0      1.0  Don't waste your money      1391040000  01 30, 2014
#
#                                          description  \
# 0  An extensive range of 15 multiple vibrant long...
#
#                                                title  \
# 0  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
#
#                                                imUrl          salesRank  \
# 0  http://ecx.images-amazon.com/images/I/41Rn18Oe...  {'Beauty': 10486}
#
#                                           categories  price  \
# 0  [['Beauty', 'Makeup', 'Face', 'Concealers & Ne...   5.04
#
#                                              related brand
# 0  {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...  COKA

# %%
tqdm.pandas()
table_data['attributes'] = table_data.iloc[:,2:].progress_apply(lambda row : row.to_json(), axis=1)
# Out:
# 100%|██████████| 198502/198502 [00:09<00:00, 21599.11it/s]

# %%
tqdm.pandas()
table_data['attributes'][0]
# Out:
# '{"reviewerName":"Andrea","helpful":"[3, 4]","reviewText":"Very oily and creamy. Not at all what I expected... ordered this to try to highlight and contour and it just looked awful!!! Plus, took FOREVER to arrive.","overall":1.0,"summary":"Don\'t waste your money","unixReviewTime":1391040000,"reviewTime":"01 30, 2014","description":"An extensive range of 15 multiple vibrant long wear concealer colour with different skin tones to create more than 10,000 amazing looks. Using the most commonly applied shades, ensures the best skin colour match and guarantees a traceless and natural finish. Enabling layering and mixing, provides total camouflage for almost any skin problem including blemishes, scars, birthmarks and black circles. It is also suitable to use as bronzer. The light colour is suitable for redness, acne and so on. The medium colour is perfect for dark shadows in the under-eye area. The dark colour provides exceptional camouflage and adheres well to the skin. Silky glossy colour and high quality ingredients together to care skin around and can last for all day long. It is perfect for Professional Salon, Wedding, Party and Home use. Size: 15.4 x 10.2 x 1.3cm. Each Diameter: 2.6cm. Concealer: 15 Color Concealer.","title":"WAWO 15 Color Professionl Makeup Eyeshadow Camouflage Facial Concealer Neutral Palette","imUrl":"http:\\/\\/ecx.images-amazon.com\\/images\\/I\\/41Rn18OeU6L._SY300_.jpg","salesRank":"{\'Beauty\': 10486}","categories":"[[\'Beauty\', \'Makeup\', \'Face\', \'Concealers & Neutralizers\']]","price":5.04,"related":"{\'also_bought\': [\'B00KR26VFE\', \'B00E7LQHZ0\', \'B00BMW24TU\', \'B00K67AQN8\', \'B008GOR6O0\', \'B00KVBZAXK\', \'B008B2Z94Q\', \'B00IIFVJZ4\', \'B00FYUX3Z0\', \'B00HWR1OZ4\', \'B00EYZR3E8\', \'B00IHQKRCA\', \'B00KS4FDLO\', \'B00GBTX1GO\', \'B00FYVOG1Y\', \'B009WJCEMM\', \'B00ID5PRQQ\', \'B00IIG7UQ0\', \'B0068Y0EXK\', \'B00JFLRCOW\', \'B009NAE91E\', \'B00B4YVU4G\', \'B00K48JDWY\', \'B006HCJXBM\', \'B009VXY05S\', \'B00I99OON8\', \'B009WI3RZQ\', \'B00IJ3LG94\', \'B0067F8BBM\', \'B002TPQPEE\', \'B00IBVE79K\', \'B00K05ZR08\', \'B00K407VOO\', \'B00GMDIKV0\', \'B00KWSCOZO\', \'B00EL1HZ34\', \'B00HKA110G\', \'B00KL53KGA\', \'B00B8P5CTA\', \'B00EYYW2HW\', \'B00IKBGQAE\', \'B00KHKXPHS\', \'B00HPS4664\', \'B00I9ZCV6E\', \'B00EOFEKF8\', \'B00F16KHLA\', \'B00L0R8KK4\', \'B00G8F2RNE\', \'B00942W51C\', \'B00KXOLTD0\', \'B00DAYGJVW\', \'B004X1QY20\', \'B00BLDA3J8\', \'B00HL9BG9C\', \'B00GLM2FAO\', \'B00JEGCI6U\', \'B00K7P74GQ\', \'B004W5RCNM\', \'B00JK99BNE\', \'B005TKZS76\', \'B00E57MCMS\', \'B001TK1I4M\', \'B00CQ1DKZS\', \'B00FORNVGO\', \'B00GQU5YY0\', \'B00GZIHP3G\', \'B00BX7DGIC\', \'B004GNMP0U\', \'B00DQ2ILQY\', \'B00IZZ7RTO\', \'B00CBT0TYU\', \'B008NQJA5E\', \'B0092LDWVW\', \'B00HQ8MA70\', \'B003QAPTAW\', \'B004M7WKKK\', \'B00H1SW3RC\', \'B008FX7B9M\', \'B0061KQEVW\', \'B00IIFOEIS\', \'B006GTKSHY\', \'B00D8U570W\', \'B00IQK5K4C\', \'B00IZ6KIE4\', \'B00FORNYMU\', \'B00LAYIFD4\', \'B00ACOFN0Q\', \'B00BZ4QDW4\', \'B005C8MMPQ\', \'1111306923\', \'B006Z5K3FG\', \'B0054SIB1S\', \'B002UBVZYC\', \'B00J921XM4\', \'B00CZ4W8UE\', \'B00EU89CKC\', \'B00J3IFAA0\', \'B005O30Q0M\'], \'also_viewed\': [\'B008GOR6O0\', \'B00EOFEKF8\', \'B00IIFVJZ4\', \'B009C7RZNC\', \'B00K05ZR08\', \'B009NAE9A0\', \'B00A66T112\', \'B00C8R39TM\', \'B009VYF0MY\', \'B00K0683R6\', \'B004M7WKKK\', \'B00K0683OE\', \'B008MU8TL2\', \'B00HKA110G\', \'B00K0683PS\', \'B00BMW24TU\', \'B0061KQEVW\', \'B00E7LQHZ0\', \'B00KR26VFE\', \'B00IHR9EVE\', \'B00IHQKRCA\', \'B00GWDKRG6\', \'B00DFQOIJA\', \'B00GWDZBHQ\', \'B002QFGQAK\', \'B007RKC27U\', \'B00JE46HM8\', \'B00IIG7UQ0\', \'B009NAE91E\', \'B008D5JRL2\', \'B00IHR9EV4\', \'B00CZ49RSK\', \'B00J3HHJUA\', \'B009WJCEMM\', \'B004I3LU7C\', \'B00LE9YL0G\', \'B00EYZR3E8\', \'B00FQ8OL6U\', \'B00L54D9NU\', \'B00GBTX1GO\', \'B00I9GTBD4\', \'B00IVHDGMS\', \'B009P732GI\', \'B008B2Z94Q\', \'B004UO2GMW\', \'B00KHOF6V2\', \'B008D5D9NY\', \'B00IHQQGKM\', \'B00AU05YVU\', \'B00HWR1OZ4\', \'B00K67AQN8\', \'B002QFGKUQ\', \'B00 ...

# %%
table_data.to_csv(f'{dir}/rag_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 table_data.to_csv(f'{dir}/rag_data.csv')
#
# NameError: name 'table_data' is not defined
