# %%
import pandas as pd

# %%
dir = '../data/PQA/amazon_pqa_earbud_headphones.json'

df = pd.read_json(dir, lines = True)

# %%
df
# Out:
#             question_id                                      question_text  \
# 0        TxQDL02FGIM4YS  will this product work for my android htc one m8?
# 1        TxGWI9324BELEL                       Can this handle Megadeth???!
# 2       Tx2X8PYZFPNMNO2      does the micrphone work with android device ?
# 3        TxJE0O03JGE5L8                                do these have a mic
# 4       Tx2G5MQXOJVHZG8  Perhaps a silly question but, these come with ...
# ...                 ...                                                ...
# 307815  Tx1JY60G676RBDC  I purchased these headphones in december and t...
# 307816  Tx3N2D60842LFE0  What does it mean  charge up earbuds 20 times?...
# 307817   TxXK7N0L298YGD  How do you charge these headphones? Do I have ...
# 307818  Tx1SWC7ZA6IE4PV  is it possible to change between songs? To pas...
# 307819  Tx2Z01TAWUWJ13J    Are these the same headphone as on Kickstarter?
#
# ...

# %%
test = '0528881469'

print(test in df['asin'])
# Out:
# False
